# %%
from src.data_loader import load_edges
from src.graph import build_graph, basic_stats
from src.features import extract_features
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-af4b70c917ed> in <module>
# ----> 1 from src.data_loader import load_edges
#       2 from src.graph import build_graph, basic_stats
#       3 from src.features import extract_features
#
# ModuleNotFoundError: No module named 'src'

# %%
df = load_edges()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cd1a6e466191> in <module>
# ----> 1 df = load_edges()
#
# NameError: name 'load_edges' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
G = build_graph(df, min_weight=2)

basic_stats(G)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6855c9b9c4d3> in <module>
# ----> 1 G = build_graph(df, min_weight=2)
#       2
#       3 basic_stats(G)
#
# NameError: name 'build_graph' is not defined

# %%
features = extract_features(G)

features.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c1dd3fad5e6c> in <module>
# ----> 1 features = extract_features(G)
#       2
#       3 features.head()
#
# NameError: name 'extract_features' is not defined
